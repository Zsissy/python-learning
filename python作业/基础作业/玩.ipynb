# %%
import emoji
love="💛"
row1=[' 💛,💛,💛,' ',' ',💛,💛,💛']
row2=['💛,💛,💛,💛,' ',💛,💛,💛,💛']
row3=
print(row1)
print(row2)
# Out:
# [' 💛,💛,💛,,,💛,💛,💛']
# ['💛,💛,💛,💛,,💛,💛,💛,💛']

# %%
import emoji
print("\xE2\x9D\xA4")
# Out:
# â¤
