# %%
listplus=[]
for i in range(1,10):
    a=i
    for a in range(1,i):
        plus=a*i
    #listplus.append(a)
        listplus.append(plus)
        print(listplus)
# Out:
# [2]
# [2, 3]
# [2, 3, 6]
# [2, 3, 6, 4]
# [2, 3, 6, 4, 8]
# [2, 3, 6, 4, 8, 12]
# [2, 3, 6, 4, 8, 12, 5]
# [2, 3, 6, 4, 8, 12, 5, 10]
# [2, 3, 6, 4, 8, 12, 5, 10, 15]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30, 7]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30, 7, 14]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30, 7, 14, 21]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30, 7, 14, 21, 28]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30, 7, 14, 21, 28, 35]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30, 7, 14, 21, 28, 35, 42]
# [2, 3, 6, 4, 8, 12, 5, 10, 15, 20, 6, 12, 18, 24, 30, 7, 14, 21, 28, 35, 42, 8]
# ...

# %%
listplus=[]
for i in range(1,10):
    for a in range(1,i):
        a=i
        plus=a*i
    #listplus.append(a)
        listplus.append(plus)
        print(listplus)
# Out:
# [4]
# [4, 9]
# [4, 9, 9]
# [4, 9, 9, 16]
# [4, 9, 9, 16, 16]
# [4, 9, 9, 16, 16, 16]
# [4, 9, 9, 16, 16, 16, 25]
# [4, 9, 9, 16, 16, 16, 25, 25]
# [4, 9, 9, 16, 16, 16, 25, 25, 25]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36, 36]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36, 36, 49]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36, 36, 49, 49]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36, 36, 49, 49, 49]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36, 36, 49, 49, 49, 49]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36, 36, 49, 49, 49, 49, 49]
# [4, 9, 9, 16, 16, 16, 25, 25, 25, 25, 36, 36, 36, 36, 36, 49, 49, 49, 49, 49, 49]
# ...

# %%
for i in range(1,10):
    for a in range(1,i+1):
        print(f'{a}x{i}={i*a}', end='\t')  
    print()
# Out:
# 1x1=1
# 1x2=2	2x2=4
# 1x3=3	2x3=6	3x3=9
# 1x4=4	2x4=8	3x4=12	4x4=16
# 1x5=5	2x5=10	3x5=15	4x5=20	5x5=25
# 1x6=6	2x6=12	3x6=18	4x6=24	5x6=30	6x6=36
# 1x7=7	2x7=14	3x7=21	4x7=28	5x7=35	6x7=42	7x7=49
# 1x8=8	2x8=16	3x8=24	4x8=32	5x8=40	6x8=48	7x8=56	8x8=64
# 1x9=9	2x9=18	3x9=27	4x9=36	5x9=45	6x9=54	7x9=63	8x9=72	9x9=81
